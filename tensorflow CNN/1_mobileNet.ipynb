# %% [markdown]
# # CNN Model Template

# %% [markdown]
# This notebook is a template for building a CNN model.

# %% [markdown]
# ## Imports and inital setup

# %%
# Imports
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras import layers
from tensorflow.keras.models import Model

import sys

sys.path.append("..")
from helperfunctions import modelhelper as mh

SEED = 42
NUM_EPOCHS = 1

# File path variables
# please make sure to use the correct path to the meta data file

FILEPATH_JPGS = './../data/jpgs/'
FILEPATH_PROCESSED="./../data/processed/"
FILEPATH_OUTPUT = './../data/jpgs/'  # Replace with your folder path

TARGET_LABEL="dx"
BALANCE_LABEL="dx"
IMAGE_SIZE = (244, 244)

# %% [markdown]
# ### Loading (augmented) metadata as test, train, validation from files

# %%
# Read the metadata file
train_df = pd.read_csv(FILEPATH_PROCESSED+"train_from_Metadata_processed.csv")
validation_df = pd.read_csv(FILEPATH_PROCESSED+"validation_from_Metadata_processed.csv")
test_df = pd.read_csv(FILEPATH_PROCESSED+"test_from_Metadata_processed.csv")

train_df.sample(15)
# Out:
#          lesion_id                    image_id     dx    dx_type   age
# 1750   HAM_0002738            ISIC_0029438.jpg     nv      histo  65.0  \
# 7439   HAM_0007131  aug_oCQ0ApISIC_0031692.jpg  akiec      histo  60.0
# 1026   HAM_0004995            ISIC_0029869.jpg     nv  follow_up  45.0
# 2711   HAM_0004536  aug_YLt1XWISIC_0030314.jpg    bcc      histo  40.0
# 912    HAM_0007553            ISIC_0031676.jpg     nv      histo  40.0
# 802    HAM_0000615            ISIC_0026758.jpg     nv  follow_up  45.0
# 13120  HAM_0004756  aug_RS0ZI0ISIC_0029248.jpg     df      histo  55.0
# 7528   HAM_0002441  aug_sAuUY4ISIC_0031381.jpg  akiec      histo  80.0
# 7548   HAM_0006746  aug_34xl1aISIC_0026872.jpg  akiec      histo  85.0
# 10469  HAM_0003179            ISIC_0029108.jpg    bkl      histo  35.0
# 2882   HAM_0004827  aug_ain6RoISIC_0027819.jpg    bcc      histo  50.0
# 671    HAM_0001708            ISIC_0033719.jpg     nv      histo  55.0
# 8179   HAM_0005376  aug_lfz42kISIC_0025606.jpg   vasc  consensus  55.0
# 7608   HAM_0002615  aug_wkaM2dISIC_0033413.jpg  akiec      histo  70.0
# 10916  HAM_0003647  aug_SioVkkISIC_0028840.jpg    bkl      histo  60.0
#
#           sex     localization        dataset        dx_binary
# 1750   female             face      rosendahl  not_skin_cancer  \
# 7439     male             back      rosendahl      skin_cancer
# 1026   female  upper extremity  vidir_molemax  not_skin_cancer
# 2711   female             back   vidir_modern      skin_cancer
# 912      male             back   vidir_modern  not_skin_cancer
# 802      male  lower extremity  vidir_molemax  not_skin_cancer
# 13120    male  lower extremity    vienna_dias  not_skin_cancer
# 7528     male            scalp      rosendahl      skin_cancer
# 7548     male  lower extremity      rosendahl      skin_cancer
# 10469  female             face      rosendahl  not_skin_cancer
# 2882   female             back      rosendahl      skin_cancer
# 671      male  lower extremity   vidir_modern  not_skin_cancer
# 8179     male            scalp  vidir_molemax  not_skin_cancer
# 7608     male            scalp   vidir_modern      skin_cancer
# 10916    male            chest      rosendahl  not_skin_cancer
#
#                                       image_path
# 1750             ./../data/jpgs/ISIC_0029438.jpg
# 7439   ./../data/jpgs/aug_oCQ0ApISIC_0031692.jpg
# 1026             ./../data/jpgs/ISIC_0029869.jpg
# 2711   ./../data/jpgs/aug_YLt1XWISIC_0030314.jpg
# 912              ./../data/jpgs/ISIC_0031676.jpg
# 802              ./../data/jpgs/ISIC_0026758.jpg
# 13120  ./../data/jpgs/aug_RS0ZI0ISIC_0029248.jpg
# 7528   ./../data/jpgs/aug_sAuUY4ISIC_0031381.jpg
# 7548   ./../data/jpgs/aug_34xl1aISIC_0026872.jpg
# 10469            ./../data/jpgs/ISIC_0029108.jpg
# 2882   ./../data/jpgs/aug_ain6RoISIC_0027819.jpg
# 671              ./../data/jpgs/ISIC_0033719.jpg
# 8179   ./../data/jpgs/aug_lfz42kISIC_0025606.jpg
# 7608   ./../data/jpgs/aug_wkaM2dISIC_0033413.jpg
# 10916  ./../data/jpgs/aug_SioVkkISIC_0028840.jpg

# %% [markdown]
# ## Setting up the image data generator for training and validation

# %%
# Setting up the Image Data Generator for the train data set - including augmentation

datagen_train = ImageDataGenerator(
    rescale=1.0 / 255.0,  # Rescale pixel values to [0, 1], important for CNNs to perform better, deactivate to see images down below
    preprocessing_function=preprocess_input,  # Use the preprocess_input function of MobileNetV3Large
)

datagen_validation = ImageDataGenerator(
    rescale=1.0 / 255.0,
    preprocessing_function=preprocess_input
)

validation_generator = datagen_validation.flow_from_dataframe(
    dataframe=validation_df,
    directory=FILEPATH_JPGS,
    x_col="image_id",
    y_col=TARGET_LABEL,
    class_mode="categorical",
    target_size=IMAGE_SIZE,
    batch_size=32
)

train_data_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        directory=FILEPATH_JPGS,
        x_col="image_id",
        y_col=TARGET_LABEL,
        class_mode="categorical",
        target_size=IMAGE_SIZE,
        batch_size=32
)
# Out:
# Found 2003 validated image filenames belonging to 7 classes.
# Found 14006 validated image filenames belonging to 7 classes.

# %% [markdown]
# # Using MobileNet V3 large

# %%
PRETRAINED = False

if PRETRAINED:
    # Initialize the MobileNetV3Large model
    base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

    # Freeze the base model's layers to use it for feature extraction
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom layers on top 
    x = layers.Conv2D(128, (3, 3), activation='relu')(base_model.output)
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(7, activation='softmax')(x) 

    # Create the full model
    model = Model(inputs=base_model.input, outputs=x, name="MobilneNetV3Large_pretrained-weights_fixed-layers_custom-conv2D")

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

    model.summary()

else:
    # Initialize the MobileNetV3Large model
    base_model = MobileNetV3Large(weights=None, include_top=False, input_shape=(224, 224, 3))

    # Freeze the base model's layers to use it for feature extraction
    for layer in base_model.layers:
        layer.trainable = True

    # Add custom layers on top 
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(7, activation='softmax')(x) 

    # Create the full model
    model = Model(inputs=base_model.input, outputs=x, name="MobilneNetV3Large_rand-weights")

    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

    model.summary()
# Out:
# Model: "MobilneNetV3Large_rand-weights"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_8 (Rescaling)     (None, 224, 224, 3)          0         ['input_9[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_8[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_224 (  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_312 (ReLU)            (None, 112, 112, 16)         0         ['tf.__operators__.add_224[0][
#                                                                     0]']
#
#  tf.math.multiply_224 (TFOp  (None, 112, 112, 16)         0         ['re_lu_312[0][0]']
#  Lambda)
#
#  multiply_160 (Multiply)     (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_224[0][0]']
#
#  expanded_conv/depthwise (D  (None, 112, 112, 16)         144       ['multiply_160[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv/depthwise/Ba  (None, 112, 112, 16)         64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_313 (ReLU)            (None, 112, 112, 16)         0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/project (Con  (None, 112, 112, 16)         256       ['re_lu_313[0][0]']
#  v2D)
#
#  expanded_conv/project/Batc  (None, 112, 112, 16)         64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv/Add (Add)     (None, 112, 112, 16)         0         ['multiply_160[0][0]',
#                                                                      'expanded_conv/project/BatchN
#                                                                     orm[0][0]']
#
#  expanded_conv_1/expand (Co  (None, 112, 112, 64)         1024      ['expanded_conv/Add[0][0]']
#  nv2D)
#
#  expanded_conv_1/expand/Bat  (None, 112, 112, 64)         256       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_314 (ReLU)            (None, 112, 112, 64)         0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 113, 113, 64)         0         ['re_lu_314[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 56, 56, 64)           576       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 56, 56, 64)           256       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_315 (ReLU)            (None, 56, 56, 64)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 56, 56, 24)           1536      ['re_lu_315[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_316 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 56, 56, 72)           648       ['re_lu_316[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 56, 56, 72)           288       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_317 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 56, 56, 24)           1728      ['re_lu_317[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 56, 56, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_318 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 59, 59, 72)           0         ['re_lu_318[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 28, 28, 72)           1800      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_319 (ReLU)            (None, 28, 28, 72)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             0         ['re_lu_319[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             1752      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             1800      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_225 (  (None, 1, 1, 72)             0         ['expanded_conv_3/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_320 (ReLU)            (None, 1, 1, 72)             0         ['tf.__operators__.add_225[0][
#                                                                     0]']
#
#  tf.math.multiply_225 (TFOp  (None, 1, 1, 72)             0         ['re_lu_320[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, 28, 28, 72)           0         ['re_lu_319[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_225[0][0]']
#
#  expanded_conv_3/project (C  (None, 28, 28, 40)           2880      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_321 (ReLU)            (None, 28, 28, 120)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_4/depthwise   (None, 28, 28, 120)          3000      ['re_lu_321[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_322 (ReLU)            (None, 28, 28, 120)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_322[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_226 (  (None, 1, 1, 120)            0         ['expanded_conv_4/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_323 (ReLU)            (None, 1, 1, 120)            0         ['tf.__operators__.add_226[0][
#                                                                     0]']
#
#  tf.math.multiply_226 (TFOp  (None, 1, 1, 120)            0         ['re_lu_323[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_322[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_226[0][0]']
#
#  expanded_conv_4/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_324 (ReLU)            (None, 28, 28, 120)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_5/depthwise   (None, 28, 28, 120)          3000      ['re_lu_324[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_325 (ReLU)            (None, 28, 28, 120)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_325[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_227 (  (None, 1, 1, 120)            0         ['expanded_conv_5/squeeze_exci
#  TFOpLambda)                                                        te/Conv_1[0][0]']
#
#  re_lu_326 (ReLU)            (None, 1, 1, 120)            0         ['tf.__operators__.add_227[0][
#                                                                     0]']
#
#  tf.math.multiply_227 (TFOp  (None, 1, 1, 120)            0         ['re_lu_326[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_325[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_227[0][0]']
#
#  expanded_conv_5/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 28, 28, 240)          9600      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 28, 28, 240)          960       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_228 (  (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_327 (ReLU)            (None, 28, 28, 240)          0         ['tf.__operators__.add_228[0][
#                                                                     0]']
#
#  tf.math.multiply_228 (TFOp  (None, 28, 28, 240)          0         ['re_lu_327[0][0]']
#  Lambda)
#
#  multiply_161 (Multiply)     (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_228[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 29, 29, 240)          0         ['multiply_161[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_6/depthwise   (None, 14, 14, 240)          2160      ['expanded_conv_6/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_229 (  (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_328 (ReLU)            (None, 14, 14, 240)          0         ['tf.__operators__.add_229[0][
#                                                                     0]']
#
#  tf.math.multiply_229 (TFOp  (None, 14, 14, 240)          0         ['re_lu_328[0][0]']
#  Lambda)
#
#  multiply_162 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_229[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 80)           19200     ['multiply_162[0][0]']
#  onv2D)
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 200)          16000     ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 200)          800       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_230 (  (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_329 (ReLU)            (None, 14, 14, 200)          0         ['tf.__operators__.add_230[0][
#                                                                     0]']
#
#  tf.math.multiply_230 (TFOp  (None, 14, 14, 200)          0         ['re_lu_329[0][0]']
#  Lambda)
#
#  multiply_163 (Multiply)     (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_230[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 200)          1800      ['multiply_163[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 200)          800       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_231 (  (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_330 (ReLU)            (None, 14, 14, 200)          0         ['tf.__operators__.add_231[0][
#                                                                     0]']
#
#  tf.math.multiply_231 (TFOp  (None, 14, 14, 200)          0         ['re_lu_330[0][0]']
#  Lambda)
#
#  multiply_164 (Multiply)     (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_231[0][0]']
#
#  expanded_conv_7/project (C  (None, 14, 14, 80)           16000     ['multiply_164[0][0]']
#  onv2D)
#
#  expanded_conv_7/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_6/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_7/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_8/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_7/Add[0][0]']
#  nv2D)
#
#  expanded_conv_8/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_8/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_232 (  (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_331 (ReLU)            (None, 14, 14, 184)          0         ['tf.__operators__.add_232[0][
#                                                                     0]']
#
#  tf.math.multiply_232 (TFOp  (None, 14, 14, 184)          0         ['re_lu_331[0][0]']
#  Lambda)
#
#  multiply_165 (Multiply)     (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_232[0][0]']
#
#  expanded_conv_8/depthwise   (None, 14, 14, 184)          1656      ['multiply_165[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_8/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_8/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_233 (  (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_332 (ReLU)            (None, 14, 14, 184)          0         ['tf.__operators__.add_233[0][
#                                                                     0]']
#
#  tf.math.multiply_233 (TFOp  (None, 14, 14, 184)          0         ['re_lu_332[0][0]']
#  Lambda)
#
#  multiply_166 (Multiply)     (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_233[0][0]']
#
#  expanded_conv_8/project (C  (None, 14, 14, 80)           14720     ['multiply_166[0][0]']
#  onv2D)
#
#  expanded_conv_8/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_8/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_8/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_7/Add[0][0]',
#                                                                      'expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_9/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_8/Add[0][0]']
#  nv2D)
#
#  expanded_conv_9/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_9/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_234 (  (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#  TFOpLambda)                                                        Norm[0][0]']
#
#  re_lu_333 (ReLU)            (None, 14, 14, 184)          0         ['tf.__operators__.add_234[0][
#                                                                     0]']
#
#  tf.math.multiply_234 (TFOp  (None, 14, 14, 184)          0         ['re_lu_333[0][0]']
#  Lambda)
#
#  multiply_167 (Multiply)     (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_234[0][0]']
#
#  expanded_conv_9/depthwise   (None, 14, 14, 184)          1656      ['multiply_167[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_235 (  (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#  TFOpLambda)                                                        tchNorm[0][0]']
#
#  re_lu_334 (ReLU)            (None, 14, 14, 184)          0         ['tf.__operators__.add_235[0][
#                                                                     0]']
#
#  tf.math.multiply_235 (TFOp  (None, 14, 14, 184)          0         ['re_lu_334[0][0]']
#  Lambda)
#
#  multiply_168 (Multiply)     (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_235[0][0]']
#
#  expanded_conv_9/project (C  (None, 14, 14, 80)           14720     ['multiply_168[0][0]']
#  onv2D)
#
#  expanded_conv_9/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_8/Add[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 14, 14, 480)          38400     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 14, 14, 480)          1920      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
# ...
#                                                                      'tf.math.multiply_245[0][0]']
#
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            24000     ['multiply_175[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_13/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_246 (  (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#  TFOpLambda)                                                        atchNorm[0][0]']
#
#  re_lu_345 (ReLU)            (None, 7, 7, 960)            0         ['tf.__operators__.add_246[0][
#                                                                     0]']
#
#  tf.math.multiply_246 (TFOp  (None, 7, 7, 960)            0         ['re_lu_345[0][0]']
#  Lambda)
#
#  multiply_176 (Multiply)     (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_246[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_176[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_13/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_13/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_13/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_247 (  (None, 1, 1, 960)            0         ['expanded_conv_13/squeeze_exc
#  TFOpLambda)                                                        ite/Conv_1[0][0]']
#
#  re_lu_346 (ReLU)            (None, 1, 1, 960)            0         ['tf.__operators__.add_247[0][
#                                                                     0]']
#
#  tf.math.multiply_247 (TFOp  (None, 1, 1, 960)            0         ['re_lu_346[0][0]']
#  Lambda)
#
#  expanded_conv_13/squeeze_e  (None, 7, 7, 960)            0         ['multiply_176[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_247[0][0]']
#
#  expanded_conv_13/project (  (None, 7, 7, 160)            153600    ['expanded_conv_13/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_13/project/B  (None, 7, 7, 160)            640       ['expanded_conv_13/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_13/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_12/project/Bat
#                                                                     chNorm[0][0]',
#                                                                      'expanded_conv_13/project/Bat
#                                                                     chNorm[0][0]']
#
#  expanded_conv_14/expand (C  (None, 7, 7, 960)            153600    ['expanded_conv_13/Add[0][0]']
#  onv2D)
#
#  expanded_conv_14/expand/Ba  (None, 7, 7, 960)            3840      ['expanded_conv_14/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.__operators__.add_248 (  (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#  TFOpLambda)                                                        hNorm[0][0]']
#
#  re_lu_347 (ReLU)            (None, 7, 7, 960)            0         ['tf.__operators__.add_248[0][
#                                                                     0]']
#
#  tf.math.multiply_248 (TFOp  (None, 7, 7, 960)            0         ['re_lu_347[0][0]']
#  Lambda)
#
#  multiply_177 (Multiply)     (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_248[0][0]']
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            24000     ['multiply_177[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_14/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_249 (  (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#  TFOpLambda)                                                        atchNorm[0][0]']
#
#  re_lu_348 (ReLU)            (None, 7, 7, 960)            0         ['tf.__operators__.add_249[0][
#                                                                     0]']
#
#  tf.math.multiply_249 (TFOp  (None, 7, 7, 960)            0         ['re_lu_348[0][0]']
#  Lambda)
#
#  multiply_178 (Multiply)     (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_249[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_178[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_14/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_14/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_14/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_250 (  (None, 1, 1, 960)            0         ['expanded_conv_14/squeeze_exc
#  TFOpLambda)                                                        ite/Conv_1[0][0]']
#
#  re_lu_349 (ReLU)            (None, 1, 1, 960)            0         ['tf.__operators__.add_250[0][
#                                                                     0]']
#
#  tf.math.multiply_250 (TFOp  (None, 1, 1, 960)            0         ['re_lu_349[0][0]']
#  Lambda)
#
#  expanded_conv_14/squeeze_e  (None, 7, 7, 960)            0         ['multiply_178[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_250[0][0]']
#
#  expanded_conv_14/project (  (None, 7, 7, 160)            153600    ['expanded_conv_14/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_14/project/B  (None, 7, 7, 160)            640       ['expanded_conv_14/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_14/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_13/Add[0][0]',
#                                                                      'expanded_conv_14/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 960)            153600    ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 960)            3840      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_251 (  (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]']
#  TFOpLambda)
#
#  re_lu_350 (ReLU)            (None, 7, 7, 960)            0         ['tf.__operators__.add_251[0][
#                                                                     0]']
#
#  tf.math.multiply_251 (TFOp  (None, 7, 7, 960)            0         ['re_lu_350[0][0]']
#  Lambda)
#
#  multiply_179 (Multiply)     (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_251[0][0]']
#
#  flatten_7 (Flatten)         (None, 47040)                0         ['multiply_179[0][0]']
#
#  dense_12 (Dense)            (None, 128)                  6021248   ['flatten_7[0][0]']
#
#  dense_13 (Dense)            (None, 7)                    903       ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 9018503 (34.40 MB)
# Trainable params: 8994103 (34.31 MB)
# Non-trainable params: 24400 (95.31 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
# Train the model

history = model.fit(
    train_data_generator,
    epochs=NUM_EPOCHS,              
    verbose=1,                      # Adjust verbosity level
    batch_size=None,                # Set the batch size, default is 32, can be increased to speed up training
    callbacks=None,                 # List of callbacks to apply during training 
    validation_split=0.0,           # not needed as we use a validation data generator
    validation_data=validation_generator,
    shuffle=True,                   # Shuffle the training data before each epoch
    sample_weight=None,             # Set the weights for the train data set !
    class_weight=None,              # Set the weights for the classes, not needed if we use sample weights
    initial_epoch=0,                # Use this to continue training from a specific epoch
    steps_per_epoch=None,           # Set the number of steps per epoch, default is len(x_train) // batch_size
    validation_steps=None,          # Set the number of steps for validation, default is len(x_val) // batch_size
    validation_batch_size=None,     # Set the batch size for validation, default is batch_size
    validation_freq=1,              # Only relevant if validation data is a generator. Set the frequency to validate the model on the validation set
    max_queue_size=10,              # Set the max size for the generator queue
    workers=-1,                     # Set the max number of processes to generate the data in parallel, -1 means all CPUs
    use_multiprocessing=False       # Set to True if you use a generator in parallel, e.g. model.predict_generator()
)
# Out:
#  27/438 [>.............................] - ETA: 14:41 - loss: 3.7445 - accuracy: 0.1759

# %% [markdown]
# ## Plotting accuracy and loss of train and validation set

# %%
mh.model_plot_accuracy(history)

# %% [markdown]
# ## Evaluating the model on the test set

# %%
mh.model_accuracy_on_test(model, test_df, TARGET_LABEL, IMAGE_SIZE)
# Out:
# 63/63 - 2s - loss: 65.1376 - accuracy: 0.0704 - 2s/epoch - 36ms/step

# %% [markdown]
# ## Saving the model

# %%
from datetime import datetime
timestamp = datetime.now()
model_path = f"../models/model_{timestamp}.h5"
model.save(model_path)
# Out:
# /Users/stefanberkenhoff/code/capstone-healthy-skin/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
